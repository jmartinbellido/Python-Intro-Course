# %% [markdown]
# # **Intro to Python for Data Analysis**
# ## Chapter 2: DataFrames - Solutions to Exercises
# ---
# **Author:** Juan Martin Bellido
#
# **About**
# This notebooks includes solutions to exercises on Chapter 2.
#
# **Feedback?** Please share on [LinkedIn](https://www.linkedin.com/in/jmartinbellido/)

# %% [markdown]
# # Chapter 2: Exercises
# ---

# %% [markdown]
# ### Exercise #1
#
# ##### EX 1.A. Import dataframe. Select columns *'name', 'homeworld' and 'species'* for the firs 10 rows in DataFrame.
#
# ##### EX 1.B. Filter for characters that a) are not human and b) are from *homeworld* either Naboo, Endor or Kashyyyk.
#
# > *Dataset https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv*

# %%
import pandas as pd

# %%
df_starwars = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv",index_col="name")
df_starwars.head()
# Out:
#                 height  mass hair_color   skin_color eye_color  birth_year  \
# name
# Mon Mothma       150.0   NaN     auburn         fair      blue        48.0
# Yoda              66.0  17.0      white        green     brown       896.0
# Tion Medon       206.0  80.0       none         grey     black         NaN
# Ratts Tyerell     79.0  15.0       none  grey & blue   unknown         NaN
# Luke Skywalker   172.0  77.0      blond         fair      blue        19.0
#
#                 gender    homeworld         species
# name
# Mon Mothma      female    Chandrila           Human
# Yoda              male          NaN  Yoda's species
# Tion Medon        male       Utapau          Pau'an
# Ratts Tyerell     male  Aleen Minor          Aleena
# Luke Skywalker    male     Tatooine           Human

# %%
# EX 1.A
df_starwars[["homeworld","species"]].iloc[:10,:]
# Out:
#                       homeworld         species
# name
# Mon Mothma            Chandrila           Human
# Yoda                        NaN  Yoda's species
# Tion Medon               Utapau          Pau'an
# Ratts Tyerell       Aleen Minor          Aleena
# Luke Skywalker         Tatooine           Human
# R2-D2                     Naboo           Droid
# Beru Whitesun lars     Tatooine           Human
# Chewbacca              Kashyyyk         Wookiee
# Raymus Antilles        Alderaan           Human
# Mace Windu           Haruun Kal           Human

# %%
# EX 1.B
cond_1 = df_starwars["species"]!='Human'
cond_2 = df_starwars["homeworld"]=='Naboo'
cond_3 = df_starwars["homeworld"]=='Endor'
cond_4 = df_starwars["homeworld"]=='Kashyyyk'

df_starwars[cond_1 & (cond_2 | cond_3 | cond_4)]
# Out:
#                        height   mass hair_color    skin_color eye_color  \
# name
# R2-D2                    96.0   32.0        NaN  white & blue       red
# Chewbacca               228.0  112.0      brown       unknown      blue
# Rugor Nass              206.0    NaN       none         green    orange
# Tarfful                 234.0  136.0      brown         brown      blue
# Quarsh Panaka           183.0    NaN      black          dark     brown
# Roos Tarpals            224.0   82.0       none          grey    orange
# Wicket Systri Warrick    88.0   20.0      brown         brown     brown
# Ric Olié                183.0    NaN      brown          fair      blue
# Jar Jar Binks           196.0   66.0       none        orange    orange
#
#                        birth_year gender homeworld  species
# name
# R2-D2                        33.0    NaN     Naboo    Droid
# Chewbacca                   200.0   male  Kashyyyk  Wookiee
# Rugor Nass                    NaN   male     Naboo   Gungan
# Tarfful                       NaN   male  Kashyyyk  Wookiee
# Quarsh Panaka                62.0   male     Naboo      NaN
# Roos Tarpals                  NaN   male     Naboo   Gungan
# Wicket Systri Warrick         8.0   male     Endor     Ewok
# Ric Olié                      NaN   male     Naboo      NaN
# Jar Jar Binks                52.0   male     Naboo   Gungan

# %%
# EX 1.B
cond_1 = df_starwars["species"]!='Human'
cond_2 = df_starwars["homeworld"].isin(["Naboo","Endor","Kashyyyk"])

df_starwars[cond_1 & cond_2]
# Out:
#                        height   mass hair_color    skin_color eye_color  \
# name
# R2-D2                    96.0   32.0        NaN  white & blue       red
# Chewbacca               228.0  112.0      brown       unknown      blue
# Rugor Nass              206.0    NaN       none         green    orange
# Tarfful                 234.0  136.0      brown         brown      blue
# Quarsh Panaka           183.0    NaN      black          dark     brown
# Roos Tarpals            224.0   82.0       none          grey    orange
# Wicket Systri Warrick    88.0   20.0      brown         brown     brown
# Ric Olié                183.0    NaN      brown          fair      blue
# Jar Jar Binks           196.0   66.0       none        orange    orange
#
#                        birth_year gender homeworld  species
# name
# R2-D2                        33.0    NaN     Naboo    Droid
# Chewbacca                   200.0   male  Kashyyyk  Wookiee
# Rugor Nass                    NaN   male     Naboo   Gungan
# Tarfful                       NaN   male  Kashyyyk  Wookiee
# Quarsh Panaka                62.0   male     Naboo      NaN
# Roos Tarpals                  NaN   male     Naboo   Gungan
# Wicket Systri Warrick         8.0   male     Endor     Ewok
# Ric Olié                      NaN   male     Naboo      NaN
# Jar Jar Binks                52.0   male     Naboo   Gungan

# %% [markdown]
# ### Exercise #2
#
#
# ##### EX 2.A. Select columns *'movie_title', 'country', 'director_name' and 'imdb_score'* for the first 10 rows in DataFrame.
# ##### EX 2.B. Select movies
# (i) produced outside the USA or with an IMDB score higher than 8.5, and
# (ii) directed by either James Cameron, Peter Jackson or Tim Burton.
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/movies.csv

# %%
import pandas as pd

# %%
df_movies = pd.read_csv('https://data-wizards.s3.amazonaws.com/datasets/movies.csv')
df_movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# EX 2.A
df_movies[["movie_title","country","director_name","imdb_score"]].iloc[:10,]
# Out:
#                                   movie_title country      director_name  \
# 0                                      Avatar     USA      James Cameron
# 1    Pirates of the Caribbean: At World's End     USA     Gore Verbinski
# 2                                     Spectre      UK         Sam Mendes
# 3                       The Dark Knight Rises     USA  Christopher Nolan
# 4  Star Wars: Episode VII - The Force Awakens     NaN        Doug Walker
# 5                                 John Carter     USA     Andrew Stanton
# 6                                Spider-Man 3     USA          Sam Raimi
# 7                                     Tangled     USA       Nathan Greno
# 8                     Avengers: Age of Ultron     USA        Joss Whedon
# 9      Harry Potter and the Half-Blood Prince      UK        David Yates
#
#    imdb_score
# 0         7.9
# 1         7.1
# 2         6.8
# 3         8.5
# 4         7.1
# 5         6.6
# 6         6.2
# 7         7.8
# 8         7.5
# 9         7.5

# %%
# EX 2.B
cond_1_1 = df_movies['country']!='USA'
cond_1_2 = df_movies['imdb_score']>8.5
cond_2 = df_movies['director_name'].isin(['James Cameron','Peter Jackson','Tim Burton'])

df_movies[(cond_1_1 | cond_1_2) & cond_2][['movie_title','country','director_name','imdb_score']]
# Out:
#                                             movie_title      country  \
# 20            The Hobbit: The Battle of the Five Armies  New Zealand
# 25                                            King Kong  New Zealand
# 267   The Lord of the Rings: The Fellowship of the Ring  New Zealand
# 335       The Lord of the Rings: The Return of the King          USA
# 336               The Lord of the Rings: The Two Towers          USA
# 3508                                     The Terminator           UK
# 3704                                 Heavenly Creatures  New Zealand
#
#       director_name  imdb_score
# 20    Peter Jackson         7.5
# 25    Peter Jackson         7.2
# 267   Peter Jackson         8.8
# 335   Peter Jackson         8.9
# 336   Peter Jackson         8.7
# 3508  James Cameron         8.1
# 3704  Peter Jackson         7.4

# %% [markdown]
# ### Exercise #3
#
# ##### EX 3.A. Import DataFrame. Select columbs "Company", "Sector" and "Revenue".
# ##### EX 3.B. Rename columb "Revenue" for "Company_Revenue".
# ##### EX 3.C. Create a new column "Profits_per_Employee" as the result of dividing column "Profits" by "Employees".
#
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv

# %%
import pandas as pd

# %%
df_fortune = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv")

# %%
# EX 3.A
df_fortune[["Company","Sector","Revenue"]]
# Out:
#                         Company                        Sector  Revenue
# 0                       Walmart                     Retailing   482130
# 1                   Exxon Mobil                        Energy   246204
# 2                         Apple                    Technology   233715
# 3            Berkshire Hathaway                    Financials   210821
# 4                      McKesson                   Health Care   181241
# ..                          ...                           ...      ...
# 995  New York Community Bancorp                    Financials     1902
# 996   Portland General Electric                        Energy     1898
# 997   Portland General Electric                        Energy     1898
# 998                     Wendy’s  Hotels, Resturants & Leisure     1896
# 999           Briggs & Stratton                   Industrials     1895
#
# [1000 rows x 3 columns]

# %%
# EX 3.B
df_fortune = df_fortune.rename(
    {"Revenue":"Company_Revenue"}
    ,axis="columns"
)

df_fortune
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  \
# 0                       General Merchandisers    Bentonville, AR
# 1                          Petroleum Refining         Irving, TX
# 2                 Computers, Office Equipment      Cupertino, CA
# 3    Insurance: Property and Casualty (Stock)          Omaha, NE
# 4                    Wholesalers: Health Care  San Francisco, CA
# ..                                        ...                ...
# 995                          Commercial Banks       Westbury, NY
# 996               Utilities: Gas and Electric       Portland, OR
# 997               Utilities: Gas and Electric       Portland, OR
# 998                             Food Services         Dublin, OH
# 999                      Industrial Machinery      Wauwatosa, WI
#
#      Company_Revenue  Profits  Employees
# 0             482130    14694    2300000
# 1             246204    16150      75600
# 2             233715    53394     110000
# 3             210821    24083     331000
# 4             181241     1476      70400
# ..               ...      ...        ...
# 995             1902      -47       3448
# 996             1898      172       2646
# 997             1898      172       2646
# 998             1896      161      21200
# 999             1895       46       5480
#
# [1000 rows x 8 columns]

# %%
# EX 3.C
df_fortune["Profits_per_Employee"] = round(df_fortune["Profits"] / df_fortune["Employees"],2)
df_fortune
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  \
# 0                       General Merchandisers    Bentonville, AR
# 1                          Petroleum Refining         Irving, TX
# 2                 Computers, Office Equipment      Cupertino, CA
# 3    Insurance: Property and Casualty (Stock)          Omaha, NE
# 4                    Wholesalers: Health Care  San Francisco, CA
# ..                                        ...                ...
# 995                          Commercial Banks       Westbury, NY
# 996               Utilities: Gas and Electric       Portland, OR
# 997               Utilities: Gas and Electric       Portland, OR
# 998                             Food Services         Dublin, OH
# 999                      Industrial Machinery      Wauwatosa, WI
#
#      Company_Revenue  Profits  Employees  Profits_per_Employee
# 0             482130    14694    2300000                  0.01
# 1             246204    16150      75600                  0.21
# 2             233715    53394     110000                  0.49
# 3             210821    24083     331000                  0.07
# 4             181241     1476      70400                  0.02
# ..               ...      ...        ...                   ...
# 995             1902      -47       3448                 -0.01
# 996             1898      172       2646                  0.07
# 997             1898      172       2646                  0.07
# 998             1896      161      21200                  0.01
# 999             1895       46       5480                  0.01
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### Exercise #4
#
# Import DataFrame. Extract top 10 companies with highest revenue in the Technology sector.
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv

# %%
import pandas as pd

# %%
df_fortune = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv")
df_fortune.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df_fortune[df_fortune['Sector']=='Technology']\
  .sort_values('Revenue',ascending=False)\
  .iloc[:10,]
# Out:
#      Rank        Company      Sector  \
# 2       3          Apple  Technology
# 17     18     Amazon.com  Technology
# 19     20             HP  Technology
# 24     25      Microsoft  Technology
# 30     31            IBM  Technology
# 35     36       Alphabet  Technology
# 50     51          Intel  Technology
# 53     54  Cisco Systems  Technology
# 76     77         Oracle  Technology
# 109   110       Qualcomm  Technology
#
#                                            Industry           Location  \
# 2                       Computers, Office Equipment      Cupertino, CA
# 17                  Internet Services and Retailing        Seattle, WA
# 19                      Computers, Office Equipment      Palo Alto, CA
# 24                                Computer Software        Redmond, WA
# 30                  Information Technology Services         Armonk, NY
# 35                  Internet Services and Retailing  Mountain View, CA
# 50   Semiconductors and Other Electronic Components    Santa Clara, CA
# 53       Network and Other Communications Equipment       San Jose, CA
# 76                                Computer Software   Redwood City, CA
# 109      Network and Other Communications Equipment      San Diego, CA
#
#      Revenue  Profits  Employees
# 2     233715    53394     110000
# 17    107006      596     230800
# 19    103355     4554     287000
# 24     93580    12193     118000
# 30     82461    13190     411798
# 35     74989    16348      61814
# 50     55355    11420     107300
# 53     49161     8981      71833
# 76     38226     9938     132000
# 109    25281     5271      33000

# %% [markdown]
# ### Exercise #5
#
# ##### Import dataframe. Extract top 10 Sci-Fi movies with highest IMDB score; select only the following fields: *title_year*, *director_name* and *imdb_score*.
#
# > Dataset https://data-wizards.s3.amazonaws.com/datasets/movies.csv

# %%
import pandas as pd

# %%
df_movies = pd.read_csv('https://data-wizards.s3.amazonaws.com/datasets/movies.csv')
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
# creamos una condición, reconociendo un patrón en un campo de tipo texto
cond_1 = df_movies['genres'].str.contains('Sci-Fi', regex=False, case=False)

# filtramos por filas que cumplen la condiciñón, ordenamos, seleccionamos primeras 10 entradas y seleccionamos determinadas columnas
df_movies[cond_1]\
  .sort_values('imdb_score',ascending=False)\
  .iloc[:10,:]\
  .loc[:,['title_year','director_name','imdb_score']]
# Out:
#       title_year      director_name  imdb_score
# 453          NaN                NaN         8.8
# 2031      1980.0     Irvin Kershner         8.8
# 97        2010.0  Christopher Nolan         8.8
# 647       1999.0     Lana Wachowski         8.7
# 2973      1977.0       George Lucas         8.7
# 96        2014.0  Christopher Nolan         8.6
# 1026         NaN                NaN         8.5
# 3220      1979.0       Ridley Scott         8.5
# 1222      2006.0  Christopher Nolan         8.5
# 285       1991.0      James Cameron         8.5
